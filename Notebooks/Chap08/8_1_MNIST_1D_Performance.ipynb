# %% [markdown]
# <a href="https://colab.research.google.com/github/jinwu-5/UnderstandingDeepLearning/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-iz8jzitx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-iz8jzitx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=22618728bc94a1eece1adc98805795c044657954d3bbd0e37d99ca9a8c3e6440
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2ih5d0f6/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# Two hidden layers (100 units each) with ReLU activations
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)

def weights_init(layer_in):
    # He (Kaiming) initialization for layers feeding ReLU
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_normal_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)

# Apply initialization
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.608718, train error 61.38,  test loss 1.695313, test error 67.60
# Epoch     1, train loss 1.383476, train error 52.33,  test loss 1.534057, test error 61.00
# Epoch     2, train loss 1.163617, train error 43.20,  test loss 1.339326, test error 52.80
# Epoch     3, train loss 1.027108, train error 38.30,  test loss 1.293601, test error 49.90
# Epoch     4, train loss 0.897385, train error 32.78,  test loss 1.223623, test error 48.80
# Epoch     5, train loss 0.791245, train error 27.68,  test loss 1.138805, test error 42.70
# Epoch     6, train loss 0.725948, train error 25.60,  test loss 1.166627, test error 44.60
# Epoch     7, train loss 0.627158, train error 20.65,  test loss 1.103248, test error 41.40
# Epoch     8, train loss 0.580403, train error 20.07,  test loss 1.142971, test error 41.50
# Epoch     9, train loss 0.497127, train error 16.10,  test loss 1.074431, test error 40.20
# Epoch    10, train loss 0.422015, train error 12.25,  test loss 1.090216, test error 39.00
# Epoch    11, train loss 0.393362, train error 11.82,  test loss 1.099508, test error 39.70
# Epoch    12, train loss 0.344885, train error 8.72,  test loss 1.119642, test error 40.40
# Epoch    13, train loss 0.328333, train error 8.57,  test loss 1.105397, test error 39.90
# Epoch    14, train loss 0.288733, train error 6.88,  test loss 1.106052, test error 38.70
# Epoch    15, train loss 0.259115, train error 5.55,  test loss 1.114468, test error 38.10
# Epoch    16, train loss 0.247166, train error 5.70,  test loss 1.150447, test error 39.50
# Epoch    17, train loss 0.228186, train error 5.28,  test loss 1.201848, test error 39.30
# Epoch    18, train loss 0.206702, train error 4.03,  test loss 1.181418, test error 39.90
# Epoch    19, train loss 0.205944, train error 5.25,  test loss 1.218305, test error 38.70
# Epoch    20, train loss 0.159667, train error 2.07,  test loss 1.211029, test error 38.60
# Epoch    21, train loss 0.147914, train error 1.78,  test loss 1.214228, test error 39.00
# Epoch    22, train loss 0.142660, train error 1.30,  test loss 1.214567, test error 39.20
# Epoch    23, train loss 0.135439, train error 1.40,  test loss 1.233120, test error 38.80
# Epoch    24, train loss 0.126212, train error 1.10,  test loss 1.237853, test error 38.10
# Epoch    25, train loss 0.126320, train error 1.25,  test loss 1.277081, test error 38.50
# Epoch    26, train loss 0.116611, train error 0.95,  test loss 1.259516, test error 38.10
# Epoch    27, train loss 0.108761, train error 0.65,  test loss 1.274312, test error 39.20
# Epoch    28, train loss 0.105197, train error 0.62,  test loss 1.270165, test error 38.60
# Epoch    29, train loss 0.099036, train error 0.45,  test loss 1.286339, test error 38.00
# Epoch    30, train loss 0.094402, train error 0.40,  test loss 1.285944, test error 37.80
# Epoch    31, train loss 0.091127, train error 0.35,  test loss 1.304685, test error 38.20
# Epoch    32, train loss 0.088995, train error 0.28,  test loss 1.313567, test error 38.20
# Epoch    33, train loss 0.086496, train error 0.25,  test loss 1.300149, test error 37.90
# Epoch    34, train loss 0.084913, train error 0.25,  test loss 1.316079, test error 38.20
# Epoch    35, train loss 0.082593, train error 0.20,  test loss 1.314726, test error 38.20
# Epoch    36, train loss 0.081061, train error 0.15,  test loss 1.321892, test error 38.10
# Epoch    37, train loss 0.079056, train error 0.18,  test loss 1.325614, test error 38.20
# Epoch    38, train loss 0.077253, train error 0.12,  test loss 1.339203, test error 37.80
# Epoch    39, train loss 0.075337, train error 0.12,  test loss 1.339711, test error 38.20
# Epoch    40, train loss 0.074160, train error 0.15,  test loss 1.337668, test error 38.20
# Epoch    41, train loss 0.073522, train error 0.15,  test loss 1.340190, test error 37.80
# Epoch    42, train loss 0.072376, train error 0.07,  test loss 1.343745, test error 38.10
# Epoch    43, train loss 0.071698, train error 0.10,  test loss 1.347771, test error 38.10
# Epoch    44, train loss 0.070856, train error 0.07,  test loss 1.349942, test error 38.10
# Epoch    45, train loss 0.070106, train error 0.10,  test loss 1.352314, test error 38.10
# Epoch    46, train loss 0.069399, train error 0.07,  test loss 1.356267, test error 37.90
# Epoch    47, train loss 0.068649, train error 0.07,  test loss 1.358663, test error 38.10
# Epoch    48, train loss 0.067899, train error 0.07,  test loss 1.361669, test error 37.90
# Epoch    49, train loss 0.067303, train error 0.07,  test loss 1.364810, test error 37.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
